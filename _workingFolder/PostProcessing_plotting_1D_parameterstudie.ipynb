# %% [markdown]
# # Postprocessing of Generation results
#
# Plotting of parameterstudies etc

# %%
import pickle
import pandas as pd
import os
import matplotlib
import math as m

# %%
#Util functions
def create_folder_if_not_exists(folder_path):
    if not os.path.exists(folder_path):
        try:
            os.makedirs(folder_path)
            print(f"Folder '{folder_path}' created successfully.")
        except OSError as e:
            print(f"Error creating folder '{folder_path}': {e}")

# %% [markdown]
# ## Retrieve results

# %% [markdown]
# ### mesh size 1

# %%
# NEW: Eingabe
idx_s1=244
start_id = 0
end_id = 14
step='step_4'
var_par='t_w'
unit=' [mm]'

df_xy_1=None

#current_directory = os.getcwd()

xy_file_name='CFBData\\{}_Batch\\{}_CFB_xy.csv'.format(idx_s1,idx_s1)

df_xy_1=pd.read_csv(xy_file_name)
df_xy_1[[var_par,'eta_min_s','x_s','y_s','z_s','Location_s','GP_count_s','eta_min_c','x_c','y_c','z_c','Location_c','GP_count_c']]
# Out:
#             t_w  eta_min_s          x_s          y_s          z_s Location_s  \
# 0    200.000000   2.282458  8789.082031  5547.058594 -3941.226074      eta_4
# 1    271.428571   3.841255  2883.812744  5440.061523 -3931.532715      eta_4
# 2    342.857143   5.990993  3139.815430  5333.004883 -3738.823242      eta_4
# 3    414.285714   8.256179  2721.919189  5225.917969 -3915.376953      eta_4
# 4    485.714286  11.113333  9620.230469  2300.887451 -1107.692261      eta_1
# 5    557.142857  12.187130  9052.802734   231.155014 -1561.765259      eta_4
# 6    628.571429  14.904444  9052.802734   266.846375 -1561.765259      eta_4
# 7    700.000000  17.520462  8919.362305   302.542358 -1561.765259      eta_4
# 8    771.428571  20.749308  9198.716797   338.241760 -1561.765259      eta_4
# 9    842.857143  27.706585   632.438599   373.943665 -1296.934692      eta_4
# 10   914.285714  35.904312  4178.961426   409.647491 -1561.765259      eta_4
# ...

# %% [markdown]
# ### mesh size 3

# %%
# NEW: Eingabe
idx_s3=312
start_id = 0
end_id = 14
step='step_4'
var_par='d1_plate'
unit=' [mm]'

df_xy_3=None

#current_directory = os.getcwd()

xy_file_name='CFBData\\{}_Batch\\{}_CFB_xy.csv'.format(idx_s3,idx_s3)

df_xy_3=pd.read_csv(xy_file_name)
df_xy_3[[var_par,'eta_min_s','x_s','y_s','z_s','Location_s','GP_count_s','eta_min_c','x_c','y_c','z_c','Location_c','GP_count_c']]
# Out:
#      d1_plate  eta_min_s  x_s  y_s  z_s  Location_s  GP_count_s  eta_min_c  \
# 0   10.000000        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 1   11.428571        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 2   12.857143        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 3   14.285714        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 4   15.714286        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 5   17.142857        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 6   18.571429        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 7   20.000000        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 8   21.428571        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 9   22.857143        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# 10  24.285714        0.0  NaN  NaN  NaN         NaN         NaN        0.0
# ...

# %% [markdown]
# ## Only mesh size 1

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(df_xy_1[var_par], df_xy_1['eta_min_s'],label='Steel Reinforcement (ms=1t)', marker='o', color='darkblue')
ax.plot(df_xy_1[var_par], df_xy_1['eta_min_c'], label='Concrete (ms=1t)', marker='x', color='green')

ax.set(xlabel=var_par+unit, ylabel='$\eta \ min$ [-]',
       title='Concrete Frame Bridge, Studie {}'.format(idx_s2))

ax.set_ylim(bottom=0,top=20)
ax.axhline(y=1, color='red', linestyle='--', linewidth=1, label='$\mu=1$')

ax.grid()
ax.legend()

#fig.savefig("test.png")
# plt.show()

# %%
# save figure
figname='eta_plot_var_{}'.format(var_par)
fig_folder_path='CFBData\\{}_Batch\\_figures'.format(idx_s2)
create_folder_if_not_exists(fig_folder_path)
fig.savefig(fig_folder_path+"\\"+figname+".png")

# %% [markdown]
# ## Only mesh size 3

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(df_xy_3[var_par], df_xy_3['eta_min_s'],label='Steel Reinforcement (ms=1t)', marker='o', color='lightblue')
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_c'], label='Concrete (ms=1t)', marker='x', color='lightgreen')

ax.set(xlabel=var_par+unit, ylabel='$\eta \ min$ [-]',
       title='Concrete Frame Bridge, Studie {}'.format(idx_s3))

ax.set_ylim(bottom=0,top=20)
ax.axhline(y=1, color='red', linestyle='--', linewidth=1, label='$\mu=1$')

ax.grid()
ax.legend()

#fig.savefig("test.png")
# plt.show()

# %%
# save figure
figname='eta_plot_var_{}'.format(var_par)
fig_folder_path='CFBData\\{}_Batch\\_figures'.format(idx_s3)
create_folder_if_not_exists(fig_folder_path)
fig.savefig(fig_folder_path+"\\"+figname+".png")
# Out:
# Folder 'CFBData\65_Batch\_figures' created successfully.

# %% [markdown]
# ## Both of them

# %%
import matplotlib.pyplot as plt

cm = 1/2.54

fig, ax = plt.subplots(figsize=(25*cm,15*cm))
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_s'],label='Steel Reinforcement (ms=3t)', marker='o', color='lightblue')
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_c'], label='Concrete (ms=3t)', marker='x', color='lightgreen')

ax.plot(df_xy_1[var_par], df_xy_1['eta_min_s'],label='Steel Reinforcement (ms=1t)', marker='o', color='darkblue')
ax.plot(df_xy_1[var_par], df_xy_1['eta_min_c'], label='Concrete (ms=1t)', marker='x', color='green')

ax.set(xlabel=var_par+unit, ylabel='$\eta \ min$ [-]',
       title='Concrete Frame Bridge, Studie {} and {}'.format(idx_s1,idx_s3))

ax.set_ylim(bottom=0,top=7)
ax.axhline(y=1, color='red', linestyle='--', linewidth=1, label='$\mu=1$')

ax.grid()
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
fig.tight_layout()
 
#fig.savefig("test.png")
# plt.show()

# %%
# save figure
figname='eta_plot_var_{}_{}vs{}'.format(var_par,idx_s1,idx_s3)
fig_folder_path='CFBData\\{}_Batch\\_figures'.format(idx_s3)
create_folder_if_not_exists(fig_folder_path)
fig.savefig(fig_folder_path+"\\"+figname+".png")

# %% [markdown]
# ## Both specials trials

# %%
import matplotlib.pyplot as plt
import numpy as np

cm = 1/2.54

fig, ax = plt.subplots(figsize=(25*cm,15*cm))
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_s'],label='Steel Reinforcement (ms=3t)', marker='o', color='lightblue')
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_c'], label='Concrete (ms=3t)', marker='x', color='lightgreen')

ax.plot(df_xy_1[var_par], df_xy_1['eta_min_s'],label='Steel Reinforcement (ms=1t)', marker='o', color='darkblue')
ax.plot(df_xy_1[var_par], df_xy_1['eta_min_c'], label='Concrete (ms=1t)', marker='x', color='green')

ax.set(xlabel=var_par+unit, ylabel='$\eta \ min$ [-]',
       title='Concrete Frame Bridge, Studie {} and {}'.format(idx_s1,idx_s3))

upper_lim = 120

ax.set_ylim(bottom=0,top=upper_lim)
ax.axhline(y=1, color='red', linestyle='--', linewidth=1, label='$\mu=1$')

ax.set_xticks(df_xy_3[var_par])
labels = ax.get_xticklabels()
ax.set_xticklabels(labels, rotation=45)

ax.set_yticks(np.linspace(0,upper_lim,13))

ax.grid()
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
fig.tight_layout()

# %%
# save figure
figname='eta_plot_var_{}_{}vs{}'.format(var_par,idx_s1,idx_s3)
fig_folder_path= "D:/ETHZ/IBK-SBB/VII. 1D Parameterstudie Geometrie/Images/New meshing"
create_folder_if_not_exists(fig_folder_path)
fig.savefig(fig_folder_path+"\\"+figname+".png")

# %% [markdown]
# ## Shearplots

# %%
import matplotlib.pyplot as plt

cm = 1/2.54

fig, ax = plt.subplots(figsize=(25*cm,15*cm))
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_shear'],label='Shear stress (ms=3t)', marker='o', color=("orangered",0.3))
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_shear_reduced'],label='Shear stress within bounds (ms=3t)', marker='o', color=("deeppink",0.3))

ax.plot(df_xy_1[var_par], df_xy_1['eta_min_shear'],label='Shear stress (ms=1t)', marker='o', color='orangered')
ax.plot(df_xy_1[var_par], df_xy_1['eta_min_shear_reduced'],label='Shear stress within bounds (ms=1t)', marker='o', color='deeppink')


ax.set(xlabel=var_par+unit, ylabel='$\eta \ min$ [-]',
       title='Concrete Frame Bridge, Studie {} and {}'.format(idx_s1,idx_s3))

ax.set_ylim(bottom=0,top=1.1)
ax.axhline(y=1, color='red', linestyle='--', linewidth=1, label='$\mu=1$')

ax.grid()
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
fig.tight_layout()

# %%
# save figure
figname='eta_plot_shear_var_{}_{}vs{}'.format(var_par,idx_s1,idx_s3)
fig_folder_path='CFBData\\{}_Batch\\_figures'.format(idx_s3)
create_folder_if_not_exists(fig_folder_path)
fig.savefig(fig_folder_path+"\\"+figname+".png")

# %% [markdown]
# ## Shearplots special trials

# %%
import matplotlib.pyplot as plt
import numpy as np

cm = 1/2.54

fig, ax = plt.subplots(figsize=(25*cm,15*cm))
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_shear'],label='Shear stress (ms=3t)', marker='o', color=("orangered",0.3))
ax.plot(df_xy_3[var_par], df_xy_3['eta_min_shear_reduced'],label='Shear stress within bounds   \n(ms=3t)', marker='o', color=("deeppink",0.3))

ax.plot(df_xy_1[var_par], df_xy_1['eta_min_shear'],label='Shear stress (ms=1t)', marker='o', color='orangered')
ax.plot(df_xy_1[var_par], df_xy_1['eta_min_shear_reduced'],label='Shear stress within bounds   \n(ms=1t)', marker='o', color='deeppink')


ax.set(xlabel=var_par+unit, ylabel='$\eta \ min$ [-]',
       title='Concrete Frame Bridge, Studie {} and {}'.format(idx_s1,idx_s3))

upper_lim = 15

ax.set_ylim(bottom=0,top=upper_lim)
ax.axhline(y=1, color='red', linestyle='--', linewidth=1, label='$\mu=1$')

ax.set_xticks(df_xy_3[var_par])
labels = ax.get_xticklabels()
ax.set_xticklabels(labels, rotation=45)

ax.set_yticks(np.linspace(0,upper_lim,16))

ax.grid()
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
fig.tight_layout()

# %%
# save figure
figname='eta_plot_shear_var_{}_{}vs{}'.format(var_par,idx_s1,idx_s3)
fig_folder_path= "D:/ETHZ\IBK-SBB/VII. 1D Parameterstudie Geometrie/Images/New meshing"
create_folder_if_not_exists(fig_folder_path)
fig.savefig(fig_folder_path+"\\"+figname+".png")
